# %%
import polars as pl
import os
import re
import asyncio
import json
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from sklearn.model_selection import train_test_split
from tenacity import retry, stop_after_attempt, wait_exponential
from openai import AsyncOpenAI

# Патч для Jupyter/Kaggle
import nest_asyncio
nest_asyncio.apply()

# ==========================================
# 1. КОНФИГУРАЦИЯ DEEPSEEK
# ==========================================

API_KEY = os.getenv("NOVITA_API_KEY", "dljjfnsdkjfhsajfhsaksafasM") 
BASE_URL = "https://api.novita.ai/openai"
MODEL_NAME = "deepseek/deepseek-v3.2"

# Инициализация клиента
client = AsyncOpenAI(
    api_key=API_KEY,
    base_url=BASE_URL,
)

# Настройка задержки
DELAY_SECONDS = 20

print(f"Using Model: {MODEL_NAME}")
# Out:
# Using Model: deepseek/deepseek-v3.2

# %%
# ==========================================
# 2. ПОДГОТОВКА ДАННЫХ
# ==========================================
mbti_df = pl.read_csv("/kaggle/input/mbti-type/mbti_1.csv") 
_, mbti_sample_pd = train_test_split(mbti_df.to_pandas(), test_size=800, stratify=mbti_df["type"].to_list(), random_state=69)
mbti_sample = pl.from_pandas(mbti_sample_pd)
print(f"MBTI Sample: {len(mbti_sample)}")
# Out:
# MBTI Sample: 800

# %%
# ==========================================
# 3. ASYNC INFERENCE ENGINE (OPENAI CLIENT)
# ==========================================

@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
async def get_llm_response(messages_list):
    """
    Асинхронный запрос через AsyncOpenAI (Novita).
    """
    try:
        response = await client.chat.completions.create(
            model=MODEL_NAME,
            messages=messages_list,
            max_tokens=1024,
            temperature=0.5,
            response_format={"type": "json_object"} 
        )
        return response.choices[0].message.content
            
    except Exception as e:
        print(f"Request Failed: {e}")
        raise e

async def process_row(row, instruction_fn, parse_fn):
    """
    Обработка одной строки с разделением контекста
    """
    # 1. Формируем текст данных (посты)
    user_data_text = f"User Posts Data:\n{row['posts'][:3000]}"
    
    # 2. Формируем инструкцию
    instruction_text = instruction_fn()
    
    # 3. Создаем ИСТОРИЮ сообщений (контекст)
    messages = [
        {"role": "user", "content": user_data_text},
        {"role": "user", "content": instruction_text} 
    ]

    try:
        reply = await get_llm_response(messages)
        
        if reply is None:
            return None
            
        parsed = parse_fn(reply, row)
        return parsed
    except Exception as e:
        print(f"Failed to process row ID {row.get('id', 'unknown')}: {e}")
        return None

async def run_inference_with_delay(df, instruction_fn, parse_fn, max_rows=None):
    """
    Последовательная обработка
    """
    if max_rows and len(df) > max_rows:
        print(f"Limiting to first {max_rows} rows...")
        df = df.head(max_rows)

    results = []
    total_rows = len(df)
    
    print(f"Starting inference for {total_rows} rows.")
    
    for i, row in enumerate(df.iter_rows(named=True)):
        # 1. Запрос
        res = await process_row(row, instruction_fn, parse_fn)
        results.append(res)
        
        # 2. Лог
        valid_status = res is not None and res.get('type_pred') != "XXXX"
        print(f"[{i+1}/{total_rows}] Processed. Result valid: {valid_status}")

        # 3. Пауза
        if i < total_rows - 1:
            await asyncio.sleep(DELAY_SECONDS)
    
    valid_results = [r for r in results if r is not None]
    return pl.DataFrame(valid_results)

# %%
# ==========================================
# 4. ПРОМПТЫ И МЕТРИКИ
# ==========================================

def get_mbti_instructions():
    """
    Возвращает ТОЛЬКО инструкцию и требования к формату.
    """
    return """Analyze the text data provided in the previous message to determine the author's MBTI type.

Evaluate based on these 4 dimensions:
1. (E) Extraversion vs (I) Introversion
2. (S) Sensing vs (N) Intuition
3. (T) Thinking vs (F) Feeling
4. (J) Judging vs (P) Perceiving

RETURN FORMAT:
You must return a valid JSON object ONLY:
{
  "reasoning": "Short analysis here...",
  "predicted_type": "INTJ"
}
"""

def mbti_parse(reply, row):
    try:
        # Очистка от маркдауна json
        clean_reply = reply.replace("```json", "").replace("```", "").strip()
        
        # 1. Пробуем парсить JSON
        json_match = re.search(r"\{.*\}", clean_reply, re.DOTALL)
        if json_match:
            data = json.loads(json_match.group(0))
            pred = data.get("predicted_type", "XXXX").upper()
            return {"type_true": row["type"], "type_pred": pred}
        
        # 2. Fallback regex (на случай сбоя JSON)
        strict_match = re.search(r"Type:?\s*\*?\*?([IE][NS][TF][JP])", reply, re.IGNORECASE)
        if strict_match:
            return {"type_true": row["type"], "type_pred": strict_match.group(1).upper()}

        simple_match = re.search(r"\b([IE][NS][TF][JP])\b", reply.upper())
        if simple_match:
             return {"type_true": row["type"], "type_pred": simple_match.group(1)}

        return {"type_true": row["type"], "type_pred": "XXXX"}
        
    except Exception as e:
        print(f"Parse Error: {e} | Reply snippet: {reply[:50]}...")
        return {"type_true": row["type"], "type_pred": "XXXX"}

all_metrics_data = []
def calculate_metrics(y_true, y_pred, task_name, dataset_name):
    valid_data = [(t, p) for t, p in zip(y_true, y_pred) if p != "XXXX" and len(p) == 4]
    
    if not valid_data:
        print(f"[{dataset_name}] No valid predictions to calculate metrics.")
        return

    y_true_clean = [x[0] for x in valid_data]
    y_pred_clean = [x[1] for x in valid_data]
    n = len(y_true_clean)

    print(f"\n--- Metrics for {task_name} (N={n}) ---")
    acc = accuracy_score(y_true_clean, y_pred_clean)
    _, _, f1_macro, _ = precision_recall_fscore_support(y_true_clean, y_pred_clean, average='macro', zero_division=0)

    print(f"Exact Match Accuracy: {acc:.2%}")
    print(f"Macro F1-Score:       {f1_macro:.2%}")

    axes = ["(I)E", "(N)S", "(T)F", "(J)P"]
    axis_scores = []
    total_letters_correct = 0
    for i in range(4):
        correct_count = sum(1 for t, p in zip(y_true_clean, y_pred_clean) if t[i] == p[i])
        axis_acc = correct_count / n
        axis_scores.append(axis_acc)
        total_letters_correct += correct_count
        print(f"Axis {axes[i]} Accuracy:      {axis_acc:.2%}")

    avg_letters = total_letters_correct / n
    print(f"Avg Letters Correct:  {avg_letters:.2f} / 4.00")
    
    all_metrics_data.append({
        "Dataset": dataset_name,
        "Exact_Acc": acc,
        "Macro_F1": f1_macro,
        "Avg_Letters": avg_letters
    })

    return all_metrics_data

# %%
# ==========================================
# 5. MAIN
# ==========================================

async def main():
    if not mbti_sample.is_empty():
        print("\n=== Processing MBTI ===")
        res = await run_inference_with_delay(mbti_sample, get_mbti_instructions, mbti_parse)
        
        if not res.is_empty():
            res.write_csv("results_mbti_deepseek.csv")
            print("\nPreview of Results:")
            print(res.head())
            metrics = calculate_metrics(res["type_true"].to_list(), res["type_pred"].to_list(), "MBTI Type", "MBTI_Dataset")
        else:
            print("No results generated.")

# %%
await main()
# Out:
# === Processing MBTI ===
# Starting inference for 800 rows.
# [1/800] Processed. Result valid: True
# [2/800] Processed. Result valid: True
# [3/800] Processed. Result valid: True
# [4/800] Processed. Result valid: True
# [5/800] Processed. Result valid: True
# [6/800] Processed. Result valid: True
# [7/800] Processed. Result valid: True
# [8/800] Processed. Result valid: True
# [9/800] Processed. Result valid: True
# [10/800] Processed. Result valid: True
# [11/800] Processed. Result valid: True
# [12/800] Processed. Result valid: True
# [13/800] Processed. Result valid: True
# [14/800] Processed. Result valid: True
# [15/800] Processed. Result valid: True
# [16/800] Processed. Result valid: True
# [17/800] Processed. Result valid: True
# [18/800] Processed. Result valid: True
# [19/800] Processed. Result valid: True
# [20/800] Processed. Result valid: True
# [21/800] Processed. Result valid: True
# [22/800] Processed. Result valid: True
# [23/800] Processed. Result valid: True
# [24/800] Processed. Result valid: True
# [25/800] Processed. Result valid: True
# [26/800] Processed. Result valid: True
# [27/800] Processed. Result valid: True
# [28/800] Processed. Result valid: True
# [29/800] Processed. Result valid: True
# [30/800] Processed. Result valid: True
# [31/800] Processed. Result valid: True
# [32/800] Processed. Result valid: True
# [33/800] Processed. Result valid: True
# [34/800] Processed. Result valid: True
# [35/800] Processed. Result valid: True
# [36/800] Processed. Result valid: True
# [37/800] Processed. Result valid: True
# [38/800] Processed. Result valid: True
# [39/800] Processed. Result valid: True
# [40/800] Processed. Result valid: True
# [41/800] Processed. Result valid: True
# [42/800] Processed. Result valid: True
# [43/800] Processed. Result valid: True
# [44/800] Processed. Result valid: True
# [45/800] Processed. Result valid: True
# [46/800] Processed. Result valid: True
# [47/800] Processed. Result valid: True
# [48/800] Processed. Result valid: True
# [49/800] Processed. Result valid: True
# [50/800] Processed. Result valid: True
# [51/800] Processed. Result valid: True
# [52/800] Processed. Result valid: True
# [53/800] Processed. Result valid: True
# [54/800] Processed. Result valid: True
# [55/800] Processed. Result valid: True
# [56/800] Processed. Result valid: True
# [57/800] Processed. Result valid: True
# [58/800] Processed. Result valid: True
# [59/800] Processed. Result valid: True
# [60/800] Processed. Result valid: True
# [61/800] Processed. Result valid: True
# [62/800] Processed. Result valid: True
# [63/800] Processed. Result valid: True
# [64/800] Processed. Result valid: True
# [65/800] Processed. Result valid: True
# [66/800] Processed. Result valid: True
# [67/800] Processed. Result valid: True
# [68/800] Processed. Result valid: True
# [69/800] Processed. Result valid: True
# [70/800] Processed. Result valid: True
# [71/800] Processed. Result valid: True
# [72/800] Processed. Result valid: True
# [73/800] Processed. Result valid: True
# [74/800] Processed. Result valid: True
# [75/800] Processed. Result valid: True
# [76/800] Processed. Result valid: True
# [77/800] Processed. Result valid: True
# [78/800] Processed. Result valid: True
# [79/800] Processed. Result valid: True
# [80/800] Processed. Result valid: True
# [81/800] Processed. Result valid: True
# [82/800] Processed. Result valid: True
# [83/800] Processed. Result valid: True
# [84/800] Processed. Result valid: True
# [85/800] Processed. Result valid: True
# [86/800] Processed. Result valid: True
# [87/800] Processed. Result valid: True
# [88/800] Processed. Result valid: True
# [89/800] Processed. Result valid: True
# [90/800] Processed. Result valid: True
# [91/800] Processed. Result valid: True
# [92/800] Processed. Result valid: True
# [93/800] Processed. Result valid: True
# [94/800] Processed. Result valid: True
# [95/800] Processed. Result valid: True
# [96/800] Processed. Result valid: True
# [97/800] Processed. Result valid: True
# [98/800] Processed. Result valid: True
# [99/800] Processed. Result valid: True
# [100/800] Processed. Result valid: True
# [101/800] Processed. Result valid: True
# [102/800] Processed. Result valid: True
# [103/800] Processed. Result valid: True
# [104/800] Processed. Result valid: True
# [105/800] Processed. Result valid: True
# [106/800] Processed. Result valid: True
# [107/800] Processed. Result valid: True
# [108/800] Processed. Result valid: True
# [109/800] Processed. Result valid: True
# [110/800] Processed. Result valid: True
# [111/800] Processed. Result valid: True
# [112/800] Processed. Result valid: True
# [113/800] Processed. Result valid: True
# [114/800] Processed. Result valid: True
# [115/800] Processed. Result valid: True
# [116/800] Processed. Result valid: True
# [117/800] Processed. Result valid: True
# [118/800] Processed. Result valid: True
# [119/800] Processed. Result valid: True
# [120/800] Processed. Result valid: True
# [121/800] Processed. Result valid: True
# [122/800] Processed. Result valid: True
# [123/800] Processed. Result valid: True
# [124/800] Processed. Result valid: True
# [125/800] Processed. Result valid: True
# [126/800] Processed. Result valid: True
# [127/800] Processed. Result valid: True
# [128/800] Processed. Result valid: True
# [129/800] Processed. Result valid: True
# [130/800] Processed. Result valid: True
# [131/800] Processed. Result valid: True
# [132/800] Processed. Result valid: True
# [133/800] Processed. Result valid: True
# [134/800] Processed. Result valid: True
# [135/800] Processed. Result valid: True
# [136/800] Processed. Result valid: True
# [137/800] Processed. Result valid: True
# [138/800] Processed. Result valid: True
# [139/800] Processed. Result valid: True
# [140/800] Processed. Result valid: True
# [141/800] Processed. Result valid: True
# [142/800] Processed. Result valid: True
# [143/800] Processed. Result valid: True
# [144/800] Processed. Result valid: True
# [145/800] Processed. Result valid: True
# [146/800] Processed. Result valid: True
# [147/800] Processed. Result valid: True
# [148/800] Processed. Result valid: True
# [149/800] Processed. Result valid: True
# [150/800] Processed. Result valid: True
# [151/800] Processed. Result valid: True
# [152/800] Processed. Result valid: True
# [153/800] Processed. Result valid: True
# [154/800] Processed. Result valid: True
# [155/800] Processed. Result valid: True
# [156/800] Processed. Result valid: True
# [157/800] Processed. Result valid: True
# [158/800] Processed. Result valid: True
# [159/800] Processed. Result valid: True
# [160/800] Processed. Result valid: True
# [161/800] Processed. Result valid: True
# [162/800] Processed. Result valid: True
# [163/800] Processed. Result valid: True
# [164/800] Processed. Result valid: True
# [165/800] Processed. Result valid: True
# [166/800] Processed. Result valid: True
# [167/800] Processed. Result valid: True
# [168/800] Processed. Result valid: True
# [169/800] Processed. Result valid: True
# [170/800] Processed. Result valid: True
# [171/800] Processed. Result valid: True
# [172/800] Processed. Result valid: True
# [173/800] Processed. Result valid: True
# [174/800] Processed. Result valid: True
# [175/800] Processed. Result valid: True
# [176/800] Processed. Result valid: True
# [177/800] Processed. Result valid: True
# [178/800] Processed. Result valid: True
# [179/800] Processed. Result valid: True
# [180/800] Processed. Result valid: True
# [181/800] Processed. Result valid: True
# [182/800] Processed. Result valid: True
# [183/800] Processed. Result valid: True
# [184/800] Processed. Result valid: True
# [185/800] Processed. Result valid: True
# [750/800] Processed. Result valid: True
# [751/800] Processed. Result valid: True
# [752/800] Processed. Result valid: True
# [753/800] Processed. Result valid: True
# [754/800] Processed. Result valid: True
# [755/800] Processed. Result valid: True
# [756/800] Processed. Result valid: True
# [757/800] Processed. Result valid: True
# [758/800] Processed. Result valid: True
# [759/800] Processed. Result valid: True
# [760/800] Processed. Result valid: True
# [761/800] Processed. Result valid: True
# [762/800] Processed. Result valid: True
# [763/800] Processed. Result valid: True
# [764/800] Processed. Result valid: True
# [765/800] Processed. Result valid: True
# [766/800] Processed. Result valid: True
# [767/800] Processed. Result valid: True
# [768/800] Processed. Result valid: True
# [769/800] Processed. Result valid: True
# [770/800] Processed. Result valid: True
# [771/800] Processed. Result valid: True
# [772/800] Processed. Result valid: True
# [773/800] Processed. Result valid: True
# [774/800] Processed. Result valid: True
# [775/800] Processed. Result valid: True
# [776/800] Processed. Result valid: True
# [777/800] Processed. Result valid: True
# [778/800] Processed. Result valid: True
# [779/800] Processed. Result valid: True
# [780/800] Processed. Result valid: True
# [781/800] Processed. Result valid: True
# [782/800] Processed. Result valid: True
# [783/800] Processed. Result valid: True
# [784/800] Processed. Result valid: True
# [785/800] Processed. Result valid: True
# [786/800] Processed. Result valid: True
# [787/800] Processed. Result valid: True
# [788/800] Processed. Result valid: True
# [789/800] Processed. Result valid: True
# [790/800] Processed. Result valid: True
# [791/800] Processed. Result valid: True
# [792/800] Processed. Result valid: True
# [793/800] Processed. Result valid: True
# [794/800] Processed. Result valid: True
# [795/800] Processed. Result valid: True
# [796/800] Processed. Result valid: True
# [797/800] Processed. Result valid: True
# [798/800] Processed. Result valid: True
# [799/800] Processed. Result valid: True
# [800/800] Processed. Result valid: True
#
# Preview of Results:
# shape: (5, 2)
# ┌───────────┬───────────┐
# │ type_true ┆ type_pred │
# │ ---       ┆ ---       │
# │ str       ┆ str       │
# ╞═══════════╪═══════════╡
# │ INFJ      ┆ INFJ      │
# │ INFJ      ┆ INTJ      │
# │ INFJ      ┆ INTJ      │
# │ INFJ      ┆ INFJ      │
# │ ENFP      ┆ ENFP      │
# └───────────┴───────────┘
#
# --- Metrics for MBTI Type (N=800) ---
# Exact Match Accuracy: 52.50%
# Macro F1-Score:       45.63%
# Axis (I)E Accuracy:      85.50%
# Axis (N)S Accuracy:      91.00%
# Axis (T)F Accuracy:      76.62%
# Axis (J)P Accuracy:      76.88%
# Avg Letters Correct:  3.30 / 4.00

# %%
res = pl.read_csv("results_mbti_deepseek.csv")
metrics = calculate_metrics(res["type_true"].to_list(), res["type_pred"].to_list(), "MBTI Type", "MBTI_Dataset")

mbti_df = mbti_sample.with_columns(
    res["type_pred"]
)
mbti_df = mbti_df.rename({"type_pred": "type_pred_deepseek"})
mbti_df = mbti_df.select(["type", "type_pred_deepseek", "posts"])
mbti_df.write_csv("mbti_deepseek_predictions.csv")
# Out:
# --- Metrics for MBTI Type (N=800) ---
# Exact Match Accuracy: 52.50%
# Macro F1-Score:       45.63%
# Axis (I)E Accuracy:      85.50%
# Axis (N)S Accuracy:      91.00%
# Axis (T)F Accuracy:      76.62%
# Axis (J)P Accuracy:      76.88%
# Avg Letters Correct:  3.30 / 4.00
